# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga de un archivo csv
df= pd.read_csv('Actividad 1 Entendimiento de los Datos.csv')
df
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time              2890
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                3
# host_total_listings_count          3
# host_has_profile_pic               3
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %%
#Identificar valores nulos por dataframe
valores_nulos=df.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(58701)

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(20)
# Out:
# review_scores_location         26.422571
# review_scores_accuracy         26.422571
# review_scores_cleanliness      26.417287
# review_scores_communication    26.412004
# review_scores_rating           26.406721
# reviews_per_month              26.406721
# host_location                  23.120410
# beds                           21.413853
# price                          21.207798
# bathrooms                      21.054578
# host_response_time             15.269192
# host_response_rate             15.269192
# host_acceptance_rate           14.497807
# bedrooms                       10.868072
# has_availability                5.753685
# host_is_superhost               2.995720
# bathrooms_text                  0.042268
# maximum_minimum_nights          0.021134
# minimum_maximum_nights          0.021134
# maximum_maximum_nights          0.021134
# dtype: float64

# %%
#Valores nulos por filas
df[df.isnull().any(axis=1)]
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 7               7               353640  20250612050654  1791076  41.384220
# 10             10               360863  20250612050654  1824328  41.384280
# 11             11               363601  20250612050654  1837053  41.379610
# 13             13                36763  20250612050654   158596  41.380430
# 26             26                71520  20250612050654   366428  41.418410
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude                 neighbourhood_cleansed  \
# ...

# %% [markdown]
# SUSTITUCIÓN DE VALORES NULOS

# %%
#Primer método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
df["review_scores_accuracy"]=df["review_scores_accuracy"].fillna(round(df["review_scores_accuracy"].mean(),1))

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time              2890
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                3
# host_total_listings_count          3
# host_has_profile_pic               3
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Decidí reemplazar los valores nulos con la media, porque esta variable tiene una distribución relativamente estable y el promedio me ayuda a mantener la tendencia central sin distorsionar los datos.

# %%
#Segundo método de sustitución de valores nulos
#Sustituir valores nulos con mediana
df["review_scores_cleanliness"]=df["review_scores_cleanliness"].fillna(round(df["review_scores_cleanliness"].median(),1))

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time              2890
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                3
# host_total_listings_count          3
# host_has_profile_pic               3
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Aquí usé la mediana, ya que esta medida no se ve afectada por valores atípicos y me permite imputar los nulos de una forma más robusta.

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
df["host_listings_count"] = df["host_listings_count"].fillna(method="ffill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/3325223567.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_listings_count"] = df["host_listings_count"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time              2890
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          3
# host_has_profile_pic               3
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# A esta variable le apliqué forward fill (ffill), porque tiene registros que suelen repetirse y de esa manera aproveché la continuidad de los datos sin inventar valores.

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
df["host_total_listings_count"] = df["host_total_listings_count"].fillna(method="ffill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/1586106239.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_total_listings_count"] = df["host_total_listings_count"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time              2890
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               3
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# También usé ffill, ya que la lógica es parecida: los valores anteriores me ayudan a rellenar sin perder coherencia en los datos.

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df["host_has_profile_pic"]=df["host_has_profile_pic"].fillna(method="bfill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/3993254451.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_has_profile_pic"]=df["host_has_profile_pic"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time              2890
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Usé backfill (bfill) porque es una variable categórica con valores repetitivos y rellenar con el valor siguiente me pareció adecuado.

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df["host_response_time"]=df["host_response_time"].fillna(method="bfill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/3285020594.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_response_time"]=df["host_response_time"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                   4376
# host_response_time                 0
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Igual utilicé bfill, ya que el tiempo de respuesta de un host suele ser constante y pude completar los vacíos con valores cercanos.

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df["host_location"] =df["host_location"].fillna("Barcelona, Spain")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                      0
# host_response_time                 0
# host_response_rate              2890
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Decidí rellenar los nulos con "Barcelona, Spain", porque es la ubicación predominante en la base y me pareció lo más lógico para mantener consistencia.

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df["host_response_rate"]=df["host_response_rate"].fillna(method="bfill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/3964415756.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_response_rate"]=df["host_response_rate"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate            2744
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Aquí también usé bfill, porque la tasa de respuesta normalmente es estable, y tomar el valor siguiente me permite no dejar huecos.

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df["host_acceptance_rate"] =df["host_acceptance_rate"].fillna(method="bfill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/2539254413.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_acceptance_rate"] =df["host_acceptance_rate"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         3
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# De nuevo utilicé bfill, ya que la tasa de aceptación también es un valor que no cambia mucho entre registros.

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df["host_since"]=df["host_since"].fillna(method="bfill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/724300966.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_since"]=df["host_since"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                567
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Apliqué bfill, porque la fecha en la que un host empieza no debería variar mucho y es válido completarla con valores cercanos.

# %%
df["host_is_superhost"].value_counts()
# Out:
# host_is_superhost
# f    14234
# t     4126
# Name: count, dtype: int64

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df["host_is_superhost"]= df["host_is_superhost"].fillna("f") 
df
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             3
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df["host_identity_verified"] =df["host_identity_verified"].fillna(method="bfill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/2673152777.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_identity_verified"] =df["host_identity_verified"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                       3985
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Aquí también usé bfill, ya que la verificación de identidad es un dato binario y estable, así que tiene sentido completarlo con valores vecinos.

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df["bathrooms"]= df["bathrooms"].fillna(0) 
df
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     8
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# En este caso, puse los nulos como 0, ya que si no se especifica, lo más conservador es asumir que no hay baños registrados.

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
df["bathrooms_text"] =df["bathrooms_text"].fillna(method="ffill")
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/2966954759.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["bathrooms_text"] =df["bathrooms_text"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     0
# bedrooms                        2057
# beds                            4053
# ...

# %% [markdown]
# Utilicé ffill, porque este texto suele estar relacionado con la variable anterior y se puede heredar del registro inmediato.

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df["bedrooms"]= df["bedrooms"].fillna(0) 
df
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     0
# bedrooms                           0
# beds                            4053
# ...

# %% [markdown]
# Rellené con 0, porque si no está definido, lo más lógico es que se registraron

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df["beds"]= df["beds"].fillna(0) 
df
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     0
# bedrooms                           0
# beds                               0
# ...

# %% [markdown]
# Igual que en bedrooms, los nulos los pasé a 0, ya que sin información es mejor asumir el mínimo.

# %%
#Primer método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
df["review_scores_communication"]=df["review_scores_communication"].fillna(round(df["review_scores_communication"].mean(),1))

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     0
# bedrooms                           0
# beds                               0
# ...

# %%
#Primer método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
df["review_scores_location"]=df["review_scores_location"].fillna(round(df["review_scores_location"].mean(),1))

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# scrape_id                          0
# host_id                            0
# latitude                           0
# longitude                          0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# property_type                      0
# room_type                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_listings_count                0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     0
# bedrooms                           0
# beds                               0
# ...

# %% [markdown]
# También sustituí los nulos con la media, ya que esta calificación suele estar bien distribuida y el promedio mantiene representatividad.

# %%
#Convertir DataFrame a CSV
df.to_csv("Act 3.3 valores nulos barcelona.csv")

# %% [markdown]
# finalmete lo covertí a CSV

# %% [markdown]
# VALORES NULOS MÉXICO

# %%
df = pd.read_csv("MÉXICO1.csv")

# %%
df.shape
# Out:
# (26401, 51)

# %%
df
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 0               0                35797  20250625031918     153786  19.382830
# 1               1                44616  20250625031918     196253  19.411620
# 2               2                56074  20250625031918     265650  19.439770
# 3               3                67703  20250625031918     334451  19.411520
# 4               4                70644  20250625031918     212109  19.354480
# ...           ...                  ...             ...        ...        ...
# 26396       26396  1450299137475327273  20250625031918  170416107  19.490670
# 26397       26397  1450300528106131951  20250625031918  358250534  19.391438
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26399       26399  1450394952972090126  20250625031918   24161895  19.441713
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# scrape_id                           0
# host_id                             0
# latitude                            0
# longitude                           0
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed    26401
# property_type                       0
# room_type                           0
# host_since                        914
# host_location                    6237
# host_response_time               4686
# host_response_rate               4686
# host_acceptance_rate             3610
# host_is_superhost                1359
# host_listings_count               914
# host_total_listings_count         914
# host_has_profile_pic              914
# host_identity_verified            914
# accommodates                        0
# bathrooms                        3281
# bathrooms_text                     31
# bedrooms                          924
# beds                             3297
# ...

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(20)
# Out:
# neighbourhood_group_cleansed    100.000000
# host_location                    23.624105
# host_response_time               17.749328
# host_response_rate               17.749328
# host_acceptance_rate             13.673724
# review_scores_location           12.783607
# review_scores_communication      12.783607
# review_scores_cleanliness        12.783607
# review_scores_accuracy           12.783607
# review_scores_rating             12.776031
# reviews_per_month                12.776031
# beds                             12.488163
# bathrooms                        12.427560
# price                            12.401045
# host_is_superhost                 5.147532
# has_availability                  3.787735
# bedrooms                          3.499867
# host_listings_count               3.461990
# host_since                        3.461990
# host_total_listings_count         3.461990
# dtype: float64

# %%
df = df.drop(["neighbourhood_group_cleansed",], axis=1)
df = df.drop(["Unnamed: 0",], axis=1)

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(20)
# Out:
# host_location                  23.624105
# host_response_time             17.749328
# host_response_rate             17.749328
# host_acceptance_rate           13.673724
# review_scores_location         12.783607
# review_scores_communication    12.783607
# review_scores_cleanliness      12.783607
# review_scores_accuracy         12.783607
# review_scores_rating           12.776031
# reviews_per_month              12.776031
# beds                           12.488163
# bathrooms                      12.427560
# price                          12.401045
# host_is_superhost               5.147532
# has_availability                3.787735
# bedrooms                        3.499867
# host_total_listings_count       3.461990
# host_has_profile_pic            3.461990
# host_identity_verified          3.461990
# host_since                      3.461990
# dtype: float64

# %%
df[["host_location", "host_response_rate", "host_response_time", "review_scores_accuracy", "review_scores_location",
    "reviews_per_month", "review_scores_rating", "review_scores_communication", "review_scores_cleanliness",
    "host_acceptance_rate", "beds", "price", "bathrooms","host_is_superhost", "has_availability",
    "bedrooms", "bathrooms_text", "host_has_profile_pic", "host_total_listings_count", "host_listings_count"]].dtypes
# Out:
# host_location                   object
# host_response_rate              object
# host_response_time              object
# review_scores_accuracy         float64
# review_scores_location         float64
# reviews_per_month              float64
# review_scores_rating           float64
# review_scores_communication    float64
# review_scores_cleanliness      float64
# host_acceptance_rate            object
# beds                           float64
# price                           object
# bathrooms                      float64
# host_is_superhost               object
# has_availability                object
# bedrooms                       float64
# bathrooms_text                  object
# host_has_profile_pic            object
# host_total_listings_count      float64
# host_listings_count            float64
# dtype: object

# %%
df["host_location"].value_counts().head(5)
# Out:
# host_location
# Mexico City, Mexico         16517
# Mexico                        753
# Ciudad de México, Mexico      332
# Ciudad de Mexico, Mexico      190
# New York, NY                  184
# Name: count, dtype: int64

# %%
#Para rellenar HOST_LOCATION ocuparé un forward fill ya que en su mayoría los datos capturados en la base de datos
#original provienen de New Orleans, LA.

#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
df["host_location"] =df["host_location"].fillna(method="ffill")
df
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/3910145857.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_location"] =df["host_location"].fillna(method="ffill")
#                         id       scrape_id    host_id   latitude  longitude  \
# 0                    35797  20250625031918     153786  19.382830 -99.271780
# 1                    44616  20250625031918     196253  19.411620 -99.177940
# 2                    56074  20250625031918     265650  19.439770 -99.156050
# 3                    67703  20250625031918     334451  19.411520 -99.168570
# 4                    70644  20250625031918     212109  19.354480 -99.162170
# ...                    ...             ...        ...        ...        ...
# 26396  1450299137475327273  20250625031918  170416107  19.490670 -99.174150
# 26397  1450300528106131951  20250625031918  358250534  19.391438 -99.181881
# ...

# %%
df["host_response_rate"].value_counts().head(5)
# Out:
# host_response_rate
# 100%    17175
# 0%        641
# 99%       584
# 90%       481
# 97%       317
# Name: count, dtype: int64

# %%
#Para host_response_rate ocuparé la moda, ya que los datos faltantes representan el 22%, existe una clara moda con
#el valor de 100% y en la lista completa hay dispersión, por lo cual usar la media no sería tan óptimo.

#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto
df["host_response_rate"]= df["host_response_rate"].fillna("100%")
df
# Out:
#                         id       scrape_id    host_id   latitude  longitude  \
# 0                    35797  20250625031918     153786  19.382830 -99.271780
# 1                    44616  20250625031918     196253  19.411620 -99.177940
# 2                    56074  20250625031918     265650  19.439770 -99.156050
# 3                    67703  20250625031918     334451  19.411520 -99.168570
# 4                    70644  20250625031918     212109  19.354480 -99.162170
# ...                    ...             ...        ...        ...        ...
# 26396  1450299137475327273  20250625031918  170416107  19.490670 -99.174150
# 26397  1450300528106131951  20250625031918  358250534  19.391438 -99.181881
# 26398  1450345027980478127  20250625031918  594251711  19.419767 -99.175294
# 26399  1450394952972090126  20250625031918   24161895  19.441713 -99.161810
# 26400  1450438287340754798  20250625031918  703177347  19.427570 -99.175410
#
# ...

# %%
df["host_response_rate"].isna().sum()
# Out:
# np.int64(0)

# %%
df["host_response_time"].value_counts()
# Out:
# host_response_time
# within an hour        17811
# within a few hours     1932
# within a day           1060
# a few days or more      912
# Name: count, dtype: int64

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
df["host_response_time"] =df["host_response_time"].fillna(method="bfill")
df
# Out:
# /var/folders/dh/cmb1ntws385frzlj801tcrjc0000gn/T/ipykernel_7695/2823499583.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["host_response_time"] =df["host_response_time"].fillna(method="bfill")
#                         id       scrape_id    host_id   latitude  longitude  \
# 0                    35797  20250625031918     153786  19.382830 -99.271780
# 1                    44616  20250625031918     196253  19.411620 -99.177940
# 2                    56074  20250625031918     265650  19.439770 -99.156050
# 3                    67703  20250625031918     334451  19.411520 -99.168570
# 4                    70644  20250625031918     212109  19.354480 -99.162170
# ...                    ...             ...        ...        ...        ...
# 26396  1450299137475327273  20250625031918  170416107  19.490670 -99.174150
# 26397  1450300528106131951  20250625031918  358250534  19.391438 -99.181881
# ...

# %%
df["host_response_time"].isna().sum()
# Out:
# np.int64(1)

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(15)
# Out:
# host_acceptance_rate           13.673724
# review_scores_location         12.783607
# review_scores_communication    12.783607
# review_scores_cleanliness      12.783607
# review_scores_accuracy         12.783607
# review_scores_rating           12.776031
# reviews_per_month              12.776031
# beds                           12.488163
# bathrooms                      12.427560
# price                          12.401045
# host_is_superhost               5.147532
# has_availability                3.787735
# bedrooms                        3.499867
# host_listings_count             3.461990
# host_total_listings_count       3.461990
# dtype: float64

# %%
df["review_scores_accuracy"].value_counts()
# Out:
# review_scores_accuracy
# 5.00    4817
# 4.88     767
# 4.93     701
# 4.94     683
# 4.89     682
#         ...
# 3.64       1
# 2.89       1
# 4.02       1
# 3.93       1
# 3.14       1
# Name: count, Length: 146, dtype: int64

# %%
df["review_scores_accuracy"].describe()
# Out:
# count    23026.000000
# mean         4.782467
# std          0.369792
# min          1.000000
# 25%          4.750000
# 50%          4.880000
# 75%          4.960000
# max          5.000000
# Name: review_scores_accuracy, dtype: float64

# %%
#EN ESTE CASO SUSTITUIRÉ DE MANERA MANUAL PARA NO MODIFICAR EL #Sustituir valores nulos por un valor numérico en  concreto
df["review_scores_accuracy"]= df["review_scores_accuracy"].fillna("0")

# %%
df["review_scores_accuracy"].isna().sum()
# Out:
# np.int64(0)

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(14)
# Out:
# host_acceptance_rate           13.673724
# review_scores_location         12.783607
# review_scores_communication    12.783607
# review_scores_cleanliness      12.783607
# review_scores_rating           12.776031
# reviews_per_month              12.776031
# beds                           12.488163
# bathrooms                      12.427560
# price                          12.401045
# host_is_superhost               5.147532
# has_availability                3.787735
# bedrooms                        3.499867
# host_identity_verified          3.461990
# host_since                      3.461990
# dtype: float64

# %%
df["review_scores_location"].describe()
# Out:
# count    23026.000000
# mean         4.840647
# std          0.298201
# min          1.000000
# 25%          4.800000
# 50%          4.920000
# 75%          5.000000
# max          5.000000
# Name: review_scores_location, dtype: float64

# %%
df["review_scores_location"].value_counts()
# Out:
# review_scores_location
# 5.00    6188
# 4.94     872
# 4.96     863
# 4.95     804
# 4.93     798
#         ...
# 3.65       1
# 4.12       1
# 3.83       1
# 2.60       1
# 1.50       1
# Name: count, Length: 128, dtype: int64

# %%
#EN ESTE CASO SUSTITUIRÉ DE MANERA MANUAL PARA NO MODIFICAR EL #Sustituir valores nulos por un valor numérico en  concreto
df["review_scores_location"]= df["review_scores_location"].fillna("0")

# %%
df["review_scores_location"].isna().sum()
# Out:
# np.int64(0)

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(15)
# Out:
# host_acceptance_rate           13.673724
# review_scores_communication    12.783607
# review_scores_cleanliness      12.783607
# review_scores_rating           12.776031
# reviews_per_month              12.776031
# beds                           12.488163
# bathrooms                      12.427560
# price                          12.401045
# host_is_superhost               5.147532
# has_availability                3.787735
# bedrooms                        3.499867
# host_listings_count             3.461990
# host_identity_verified          3.461990
# host_total_listings_count       3.461990
# host_has_profile_pic            3.461990
# dtype: float64

# %%
#A partir de este momento, me di cuenta que hay cuatro valores con exactamente la misma cantidad de datos faltantes, y analizando la base de datos
#original, el tipo de datos faltantes es parecido. Por lo tanto, estaré rellenando con 0 para no modificar el comportamiento de la información og.

df["review_scores_rating"]= df["review_scores_rating"].fillna("0")
df["reviews_per_month"]= df["reviews_per_month"].fillna("0")
df["review_scores_cleanliness"]= df["review_scores_cleanliness"].fillna("0")
df["review_scores_communication"]= df["review_scores_communication"].fillna("0")

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(10)
# Out:
# host_acceptance_rate         13.673724
# beds                         12.488163
# bathrooms                    12.427560
# price                        12.401045
# host_is_superhost             5.147532
# has_availability              3.787735
# bedrooms                      3.499867
# host_identity_verified        3.461990
# host_total_listings_count     3.461990
# host_listings_count           3.461990
# dtype: float64

# %%
df[["host_acceptance_rate", "beds", "price", "bathrooms","host_is_superhost", "has_availability",
    "bedrooms", "bathrooms_text"]].dtypes
# Out:
# host_acceptance_rate     object
# beds                    float64
# price                    object
# bathrooms               float64
# host_is_superhost        object
# has_availability         object
# bedrooms                float64
# bathrooms_text           object
# dtype: object

# %%
df["host_acceptance_rate"].value_counts()
# Out:
# host_acceptance_rate
# 100%    10909
# 99%      2865
# 98%      1434
# 0%       1062
# 97%       795
#         ...
# 15%         3
# 10%         2
# 23%         2
# 26%         1
# 28%         1
# Name: count, Length: 100, dtype: int64

# %%
df["host_acceptance_rate"]= df["host_acceptance_rate"].fillna("0")

# %%
df["beds"].mode()
# Out:
# 0    1.0
# Name: beds, dtype: float64

# %%
#para este valor ocuparé la moda
df["beds"]= df["beds"].fillna("2")

# %%
df["price"]= df["price"].fillna("0")

# %%
#para el caso del precio, decidí dejarla en valores de 0 ya que existe mucha dispersión, por lo tanto no habría información verosímil si lo reempazara
#por alguna medida de tendencia central
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(6)
# Out:
# bathrooms                    12.427560
# host_is_superhost             5.147532
# has_availability              3.787735
# bedrooms                      3.499867
# host_total_listings_count     3.461990
# host_since                    3.461990
# dtype: float64

# %%
df["bathrooms"].describe()
# Out:
# count    23120.000000
# mean         1.450389
# std          1.033995
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         49.000000
# Name: bathrooms, dtype: float64

# %%
#Para la parte de baños, decidí colocar 1, ya que mínimo deben tener un baño, además de que la moda es ese valor
df["bathrooms"]= df["bathrooms"].fillna("1")

# %%
df["host_is_superhost"].value_counts()
# Out:
# host_is_superhost
# f    15365
# t     9677
# Name: count, dtype: int64

# %%
#Apartir de aquí imputaré con medidas de tendencia central ya que el porcentaje faltante es menor al 5%
df["host_is_superhost"]= df["host_is_superhost"].fillna("f")

# %%
df["has_availability"].describe()
df["has_availability"]= df["has_availability"].fillna("t")

# %%
df["bedrooms"]= df["bedrooms"].fillna("1")

# %%
df["bathrooms_text"]= df["bathrooms_text"].fillna("1 bath")

# %%
#CONOCER EL PORCENTAJE DE MISSING VALUES POR COLUMNA
porcentaje_missing = (df.isna().mean() * 100).sort_values(ascending=False)
porcentaje_missing.head(5)
# Out:
# host_listings_count          3.46199
# host_since                   3.46199
# host_identity_verified       3.46199
# host_has_profile_pic         3.46199
# host_total_listings_count    3.46199
# dtype: float64

# %%
df.to_csv("MÉXICO_CLEAN.csv")
