# %%
#INSTALAR LIBRERIAS
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertir en dataframe
df= pd.read_csv('Actividad 1 Entendimiento de los Datos.csv')
df
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %% [markdown]
# Los registros de 5 “host name” diferentes

# %%
#  a) Primeros 5 host_name diferentes
cinco_hosts = df["property_type"].unique()
cinco_hosts
# Out:
# array(['Entire rental unit', 'Entire condo', 'Entire home',
#        'Private room in rental unit', 'Entire vacation home',
#        'Entire serviced apartment', 'Entire loft',
#        'Private room in condo', 'Private room in loft',
#        'Entire townhouse', 'Private room in guest suite',
#        'Private room in floor', 'Private room in bed and breakfast',
#        'Private room in home', 'Room in serviced apartment',
#        'Private room in casa particular', 'Entire villa',
#        'Private room in guesthouse', 'Private room in hostel',
#        'Private room in serviced apartment', 'Tiny home',
#        'Private room in dome', 'Room in aparthotel',
#        'Shared room in hostel', 'Room in boutique hotel',
#        'Entire guesthouse', 'Entire guest suite', 'Entire cabin', 'Barn',
#        'Private room', 'Private room in chalet', 'Private room in villa',
#        'Private room in townhouse', 'Entire place',
# ...

# %%
tipos_elegidos = ["Room in boutique hotel", "Entire townhouse", "Entire rental unit", "Entire guest suite", "Private room in home",] 
a_result = df[df["property_type"].isin(tipos_elegidos)]
a_result
df1 = a_result.groupby(['property_type'])['property_type'].count()
df1
# Out:
# property_type
# Entire guest suite           26
# Entire rental unit        10416
# Entire townhouse             18
# Private room in home        206
# Room in boutique hotel      177
# Name: property_type, dtype: int64

# %%
f1=a_result.to_csv("fltro01.csv", index=False)

# %% [markdown]
# Los registros de los host que se hallan unido a Airbnb “despues del año 2020”

# %%
# b) Host_since > 2020
df["host_since"] = pd.to_datetime(df["host_since"], errors="coerce")
b_result = df[df["host_since"] >= "2021-01-01"]
b_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 839           839              2670047  20250612050654  510942439  41.374390
# 1019         1019              3189694  20250612050654  510942439  41.373570
# 1460         1460              5429860  20250612050654  437835392  41.404260
# 2144         2144             11814469  20250612050654  510942439  41.401420
# 2414         2414             13572127  20250612050654  537105282  41.407370
# ...           ...                  ...             ...        ...        ...
# 18900       18900  1438993628662440481  20250612050654  528129368  41.379177
# 18901       18901  1438997373129491299  20250612050654  528129368  41.379960
# 18902       18902  1439000638187447126  20250612050654  528129368  41.378966
# 18903       18903  1439004190948739706  20250612050654  514124696  41.378440
# 18915       18915  1439876945348295255  20250612050654  528129368  41.380060
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18927 entries, 0 to 18926
# Data columns (total 51 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    18927 non-null  int64
#  1   id                            18927 non-null  int64
#  2   scrape_id                     18927 non-null  int64
#  3   host_id                       18927 non-null  int64
#  4   latitude                      18927 non-null  float64
#  5   longitude                     18927 non-null  float64
#  6   neighbourhood_cleansed        18927 non-null  object
#  7   neighbourhood_group_cleansed  18927 non-null  object
#  8   property_type                 18927 non-null  object
#  9   room_type                     18927 non-null  object
#  10  host_since                    18924 non-null  datetime64[ns]
#  11  host_location                 14551 non-null  object
# ...

# %%
df2 = b_result.groupby(['host_since'])['host_since'].count()
df2
# Out:
# host_since
# 2021-01-06    1
# 2021-01-09    1
# 2021-01-11    2
# 2021-01-13    1
# 2021-01-14    5
#              ..
# 2025-05-16    1
# 2025-05-19    3
# 2025-05-26    4
# 2025-06-04    1
# 2025-06-11    2
# Name: host_since, Length: 877, dtype: int64

# %%
f2=b_result.to_csv("filtro02.csv", index=False)

# %% [markdown]
# Los registros de los host que responden “a más tardar en 1 día"

# %%
# c) Respuesta rápida (en 1 día o menos)
df3 = df.groupby(['host_response_time'])['host_response_time'].count()
df3
# Out:
# host_response_time
# a few days or more      531
# within a day           1576
# within a few hours     2794
# within an hour        11136
# Name: host_response_time, dtype: int64

# %% [markdown]
# Los registros de las filas “Múltiplos de 200… (400, 600, 800, etc.

# %%
# c) Respuesta rápida (en 1 día o menos)
rapidas = ["within an hour", "within a few hours", "within a day"]
c_result = df[df["host_response_time"].str.lower().isin(rapidas)]
c_result
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
f3=c_result.to_csv("filtro03.csv", index=False)

# %% [markdown]
# Los registros de las filas “Múltiplos de 200… (400, 600, 800, etc.)”

# %%
filas= df.iloc[0::200,:] 
filas
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 0               0                18674  20250612050654      71615  41.405560
# 200           200               694516  20250612050654    3019128  41.425930
# 400           400              1085376  20250612050654    5966973  41.395780
# 600           600              1330353  20250612050654    3799101  41.397790
# 800           800              2512546  20250612050654    3038266  41.392840
# ...           ...                  ...             ...        ...        ...
# 18000       18000  1384093592412591162  20250612050654  571289218  41.380510
# 18200       18200  1392034344774768888  20250612050654    1447144  41.380300
# 18400       18400  1407987673919415813  20250612050654   15775899  41.391032
# 18600       18600  1421600544718703815  20250612050654  212552215  41.377272
# 18800       18800  1434846226016277801  20250612050654  396940257  41.419931
#
# ...

# %%
f4=filas.to_csv("filtro04.csv", index=False)

# %% [markdown]
# Los registros de los tipos de cuarto: “Entire home” y “Private room”

# %%
df4 = df.groupby(['room_type'])['room_type'].count()
df4
# Out:
# room_type
# Entire home/apt    11657
# Hotel room            91
# Private room        7087
# Shared room           92
# Name: room_type, dtype: int64

# %%
# e) Filtrar tipos de cuarto específicos
permitidos = ["entire home/apt", "private room"]
e_result = df[df["room_type"].str.lower().isin(permitidos)]
e_result
# Out:
#        Unnamed: 0                   id       scrape_id  host_id   latitude  \
# 0               0                18674  20250612050654    71615  41.405560
# 1               1                23197  20250612050654    90417  41.412432
# 2               2                32711  20250612050654   135703  41.405660
# 3               3                34241  20250612050654    73163  41.380620
# 4               4               347824  20250612050654  1447144  41.376400
# ...           ...                  ...             ...      ...        ...
# 18922       18922  1440378586135901437  20250612050654  4459553  41.399220
# 18923       18923  1440379191108051829  20250612050654  4459553  41.399790
# 18924       18924  1440379869744969989  20250612050654  4459553  41.399390
# 18925       18925  1440380503685655376  20250612050654  4459553  41.400813
# 18926       18926  1440381140081945750  20250612050654  4459553  41.410760
#
#        longitude              neighbourhood_cleansed  \
# ...

# %%
f5=e_result.to_csv("filtro05.csv", index=False)

# %% [markdown]
# Los registros que “a lo mucho cuenten con 4 camas”

# %%
df5 = df.groupby(['beds'])['beds'].count()
df5
# Out:
# beds
# 0.0       264
# 1.0      5444
# 2.0      3201
# 3.0      2559
# 4.0      1654
# 5.0       747
# 6.0       464
# 7.0       221
# 8.0       105
# 9.0        54
# 10.0       51
# 11.0       10
# 12.0       23
# 13.0       13
# 14.0       10
# 15.0       19
# 16.0        9
# 17.0        1
# 18.0        5
# 19.0        2
# 20.0        6
# 22.0        1
# 23.0        1
# 24.0        2
# 25.0        3
# 26.0        1
# 27.0        1
# 30.0        1
# 32.0        1
# 127.0       1
# Name: beds, dtype: int64

# %%
# f) Filtro por número de camas
df["beds"] = pd.to_numeric(df["beds"], errors="coerce")
f_result = df[df["beds"] <= 4]
f_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 1               1                23197  20250612050654      90417  41.412432
# 2               2                32711  20250612050654     135703  41.405660
# 3               3                34241  20250612050654      73163  41.380620
# 4               4               347824  20250612050654    1447144  41.376400
# 6               6               352772  20250612050654    1786501  41.381840
# ...           ...                  ...             ...        ...        ...
# 18917       18917  1439929163301654408  20250612050654  333769431  41.386900
# 18918       18918  1439973901383651503  20250612050654   13530812  41.382000
# 18919       18919  1439984636030445391  20250612050654   18191427  41.389720
# 18920       18920  1440194065487969705  20250612050654  325642121  41.385540
# 18921       18921  1440349155331196931  20250612050654   49813494  41.381660
#
# ...

# %%
f6=f_result.to_csv("filtro05.csv", index=False)

# %% [markdown]
# Los registros que “sean superhost”

# %%
df6 = df.groupby(['host_is_superhost'])['host_is_superhost'].count()
df6
# Out:
# host_is_superhost
# f    14234
# t     4126
# Name: host_is_superhost, dtype: int64

# %%
# g) Filtro por superhost
g_result = df[df["host_is_superhost"] == "t"]   # o True si ya está como boolean
g_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 1               1                23197  20250612050654      90417  41.412432
# 5               5               351395  20250612050654    1435464  41.392710
# 6               6               352772  20250612050654    1786501  41.381840
# 8               8               357576  20250612050654    1809535  41.405080
# 19             19               384464  20250612050654     674212  41.389920
# ...           ...                  ...             ...        ...        ...
# 18874       18874  1436476640139020572  20250612050654  573682415  41.381748
# 18875       18875  1436479418387294109  20250612050654  573682415  41.381720
# 18876       18876  1436504753464828109  20250612050654    4959266  41.383240
# 18880       18880  1440886957702009698  20250612050654  325642121  41.387350
# 18920       18920  1440194065487969705  20250612050654  325642121  41.385540
#
# ...

# %%
f7=g_result.to_csv("filtro07.csv", index=False)

# %% [markdown]
# Los registros de las columnas “impares”

# %%
# h) Columnas en posiciones impares (1, 3, 5…)
odd_cols = [col for i, col in enumerate(df.columns, start=1) if i % 2 == 1]
h_result = df[odd_cols]
h_result
# Out:
#        Unnamed: 0       scrape_id   latitude  \
# 0               0  20250612050654  41.405560
# 1               1  20250612050654  41.412432
# 2               2  20250612050654  41.405660
# 3               3  20250612050654  41.380620
# 4               4  20250612050654  41.376400
# ...           ...             ...        ...
# 18922       18922  20250612050654  41.399220
# 18923       18923  20250612050654  41.399790
# 18924       18924  20250612050654  41.399390
# 18925       18925  20250612050654  41.400813
# 18926       18926  20250612050654  41.410760
#
#                    neighbourhood_cleansed       property_type host_since  \
# 0                      la Sagrada Família  Entire rental unit 2010-01-19
# 1                   el Besòs i el Maresme  Entire rental unit 2010-03-09
# 2      el Camp d'en Grassot i Gràcia Nova  Entire rental unit 2010-05-31
# 3                          el Barri Gòtic        Entire condo 2010-01-24
# ...

# %%
f8=h_result.to_csv("filtro08.csv", index=False)

# %% [markdown]
# EXTRACCIÓN DE DATOS MEXICO

# %%
#Convertir en dataframe
df= pd.read_csv('MÉXICO1.csv')
df
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 0               0                35797  20250625031918     153786  19.382830
# 1               1                44616  20250625031918     196253  19.411620
# 2               2                56074  20250625031918     265650  19.439770
# 3               3                67703  20250625031918     334451  19.411520
# 4               4                70644  20250625031918     212109  19.354480
# ...           ...                  ...             ...        ...        ...
# 26396       26396  1450299137475327273  20250625031918  170416107  19.490670
# 26397       26397  1450300528106131951  20250625031918  358250534  19.391438
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26399       26399  1450394952972090126  20250625031918   24161895  19.441713
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
#a) Los registros de 5 “host name” diferentes
cinco_hosts = df["property_type"].unique()
cinco_hosts
#a_result = df[df["property_type"].isin(cinco_hosts)]
#a_result.head()
# Out:
# array(['Entire villa', 'Entire home', 'Entire condo',
#        'Entire rental unit', 'Private room',
#        'Private room in rental unit', 'Entire loft',
#        'Private room in home', 'Private room in condo',
#        'Room in boutique hotel', 'Room in serviced apartment',
#        'Entire guest suite', 'Private room in townhouse',
#        'Private room in bed and breakfast', 'Private room in guest suite',
#        'Entire serviced apartment', 'Entire guesthouse', 'Tiny home',
#        'Private room in guesthouse', 'Entire bungalow',
#        'Entire townhouse', 'Private room in loft',
#        'Private room in tiny home', 'Entire cabin',
#        'Room in bed and breakfast', 'Private room in farm stay',
#        'Private room in serviced apartment',
#        'Private room in casa particular', 'Room in hotel',
#        'Private room in floor', 'Private room in cabin',
#        'Room in aparthotel', 'Entire place', 'Shared room in rental unit',
# ...

# %%
# Elige 5 tipos de propiedad específicos manualmente
tipos_elegidos = ["Entire rental unit", "Entire guest suite", "Private room in home", "Room in boutique hotel", "Entire townhouse"] 

# Filtra el DataFrame para mostrar solo las observaciones que coincidan con esos tipos
a_result = df[df["property_type"].isin(tipos_elegidos)]

# Muestra todas las observaciones filtradas (no solo .head())
a_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 3               3                67703  20250625031918     334451  19.411520
# 4               4                70644  20250625031918     212109  19.354480
# 9               9               187030  20250625031918     899360  19.410570
# 10             10              1286695  20250625031918    6998716  19.435140
# 11             11              1288566  20250625031918     540705  19.431790
# ...           ...                  ...             ...        ...        ...
# 26393       26393  1450244485815740442  20250625031918  431645813  19.350020
# 26395       26395  1450293397186325322  20250625031918  180725654  19.346430
# 26397       26397  1450300528106131951  20250625031918  358250534  19.391438
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
#Analizar categorias de una columna
df1 = a_result.groupby(['property_type'])['property_type'].count()
df1
# Out:
# property_type
# Entire guest suite          222
# Entire rental unit        10130
# Entire townhouse             52
# Private room in home       2313
# Room in boutique hotel      175
# Name: property_type, dtype: int64

# %%
f1=a_result.to_csv("f1.csv", index=False)

# %%
# b) Host_since > 2020
df["host_since"] = pd.to_datetime(df["host_since"], errors="coerce")
b_result = df[df["host_since"] >= '2021-01-01']
b_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 49             49              1850394  20250625031918  456052310  19.431220
# 1004         1004             13113108  20250625031918  451159548  19.408640
# 1312         1312             15548531  20250625031918  456052310  19.425190
# 1517         1517             16740335  20250625031918  422844046  19.441860
# 1565         1565             16884563  20250625031918  438365834  19.431483
# ...           ...                  ...             ...        ...        ...
# 26390       26390  1450214091258204699  20250625031918  468188466  19.429398
# 26391       26391  1450233077447172488  20250625031918  665095287  19.408996
# 26393       26393  1450244485815740442  20250625031918  431645813  19.350020
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26401 entries, 0 to 26400
# Data columns (total 51 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    26401 non-null  int64
#  1   id                            26401 non-null  int64
#  2   scrape_id                     26401 non-null  int64
#  3   host_id                       26401 non-null  int64
#  4   latitude                      26401 non-null  float64
#  5   longitude                     26401 non-null  float64
#  6   neighbourhood_cleansed        26401 non-null  object
#  7   neighbourhood_group_cleansed  0 non-null      float64
#  8   property_type                 26401 non-null  object
#  9   room_type                     26401 non-null  object
#  10  host_since                    25487 non-null  datetime64[ns]
#  11  host_location                 20164 non-null  object
# ...

# %%
df2 = b_result.groupby(['host_since'])['host_since'].count()
df2
# Out:
# host_since
# 2021-01-01    5
# 2021-01-02    1
# 2021-01-03    1
# 2021-01-04    1
# 2021-01-05    6
#              ..
# 2025-06-14    1
# 2025-06-16    4
# 2025-06-17    1
# 2025-06-18    1
# 2025-06-24    1
# Name: host_since, Length: 1297, dtype: int64

# %%
f2=b_result.to_csv("f2.csv", index=False)

# %%
df3 = df.groupby(['host_response_time'])['host_response_time'].count()
df3
# Out:
# host_response_time
# a few days or more      912
# within a day           1060
# within a few hours     1932
# within an hour        17811
# Name: host_response_time, dtype: int64

# %%
# c) Respuesta rápida (en 1 día o menos)
rapidas = ["within an hour", "within a few hours", "within a day"]
c_result = df[df["host_response_time"].str.lower().isin(rapidas)]
c_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 1               1                44616  20250625031918     196253  19.411620
# 2               2                56074  20250625031918     265650  19.439770
# 3               3                67703  20250625031918     334451  19.411520
# 4               4                70644  20250625031918     212109  19.354480
# 6               6               165772  20250625031918     790208  19.408260
# ...           ...                  ...             ...        ...        ...
# 26395       26395  1450293397186325322  20250625031918  180725654  19.346430
# 26396       26396  1450299137475327273  20250625031918  170416107  19.490670
# 26397       26397  1450300528106131951  20250625031918  358250534  19.391438
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26399       26399  1450394952972090126  20250625031918   24161895  19.441713
#
# ...

# %%
f3=c_result.to_csv("f3.csv", index=False)

# %%
#Filas incrementales en un fator
filas= df.iloc[0::200,:] #Filas con incrementos de 100 a partir de la fila 0 
filas
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 0               0                35797  20250625031918     153786  19.382830
# 200           200              4814757  20250625031918   12389380  19.438150
# 400           400              6572854  20250625031918   34377738  19.311030
# 600           600              8993396  20250625031918    5085423  19.444020
# 800           800             11507601  20250625031918   35406862  19.425430
# ...           ...                  ...             ...        ...        ...
# 25600       25600  1422624281706600621  20250625031918  695536587  19.426650
# 25800       25800  1434316794866247356  20250625031918  367698783  19.471717
# 26000       26000  1440073609853187910  20250625031918  440195875  19.414780
# 26200       26200  1444979774990771506  20250625031918  698035372  19.435138
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
f4=filas.to_csv("f4.csv", index=False)

# %%
df4 = df.groupby(['room_type'])['room_type'].count()
df4
# Out:
# room_type
# Entire home/apt    17235
# Hotel room            91
# Private room        8867
# Shared room          208
# Name: room_type, dtype: int64

# %%
# e) Filtrar tipos de cuarto específicos
permitidos = ["entire home/apt", "private room"]
e_result = df[df["room_type"].str.lower().isin(permitidos)]
e_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 0               0                35797  20250625031918     153786  19.382830
# 1               1                44616  20250625031918     196253  19.411620
# 2               2                56074  20250625031918     265650  19.439770
# 3               3                67703  20250625031918     334451  19.411520
# 4               4                70644  20250625031918     212109  19.354480
# ...           ...                  ...             ...        ...        ...
# 26396       26396  1450299137475327273  20250625031918  170416107  19.490670
# 26397       26397  1450300528106131951  20250625031918  358250534  19.391438
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26399       26399  1450394952972090126  20250625031918   24161895  19.441713
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
f5=e_result.to_csv("f5.csv", index=False)

# %%
df5 = df.groupby(['beds'])['beds'].count()
df5
# Out:
# beds
# 0.0       361
# 1.0     11421
# 2.0      6251
# 3.0      2791
# 4.0      1177
# 5.0       425
# 6.0       242
# 7.0       111
# 8.0        97
# 9.0        63
# 10.0       40
# 11.0       25
# 12.0       26
# 13.0        8
# 14.0       11
# 15.0        6
# 16.0       12
# 17.0        5
# 18.0        2
# 19.0        2
# 20.0        3
# 21.0        4
# 22.0        4
# 23.0        1
# 24.0        5
# 25.0        2
# 26.0        2
# 28.0        1
# 30.0        2
# 35.0        1
# 40.0        1
# 50.0        2
# Name: beds, dtype: int64

# %%
# f) Filtro por número de camas
df["beds"] = pd.to_numeric(df["beds"], errors="coerce")
f_result = df[df["beds"] <= 4]
f_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 0               0                35797  20250625031918     153786  19.382830
# 2               2                56074  20250625031918     265650  19.439770
# 3               3                67703  20250625031918     334451  19.411520
# 4               4                70644  20250625031918     212109  19.354480
# 7               7               171109  20250625031918     816295  19.396750
# ...           ...                  ...             ...        ...        ...
# 26396       26396  1450299137475327273  20250625031918  170416107  19.490670
# 26397       26397  1450300528106131951  20250625031918  358250534  19.391438
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
# 26399       26399  1450394952972090126  20250625031918   24161895  19.441713
# 26400       26400  1450438287340754798  20250625031918  703177347  19.427570
#
# ...

# %%
f6=f_result.to_csv("f6.csv", index=False)

# %%
df6 = df.groupby(['host_is_superhost'])['host_is_superhost'].count()
df6
# Out:
# host_is_superhost
# f    15365
# t     9677
# Name: host_is_superhost, dtype: int64

# %%
# g) Filtro por superhost
g_result = df[df["host_is_superhost"] == "t"]   # o True si ya está como boolean
g_result
# Out:
#        Unnamed: 0                   id       scrape_id    host_id   latitude  \
# 4               4                70644  20250625031918     212109  19.354480
# 6               6               165772  20250625031918     790208  19.408260
# 7               7               171109  20250625031918     816295  19.396750
# 8               8               180808  20250625031918      36836  19.423900
# 9               9               187030  20250625031918     899360  19.410570
# ...           ...                  ...             ...        ...        ...
# 26373       26373  1449312330909334226  20250625031918  569838375  19.372230
# 26374       26374  1449347506455590202  20250625031918  571653984  19.441612
# 26376       26376  1449724386306602095  20250625031918  151816281  19.457048
# 26393       26393  1450244485815740442  20250625031918  431645813  19.350020
# 26398       26398  1450345027980478127  20250625031918  594251711  19.419767
#
# ...

# %%
f7=g_result.to_csv("f7.csv", index=False)

# %%
# h) Columnas en posiciones impares (1, 3, 5…)
#MÉTODO 1
odd_cols = [col for i, col in enumerate(df.columns, start=0) if i % 2 == 1]
h_result = df[odd_cols]
h_result.head()
# Out:
#       id  host_id  longitude  neighbourhood_group_cleansed        room_type  \
# 0  35797   153786  -99.27178                           NaN  Entire home/apt
# 1  44616   196253  -99.17794                           NaN  Entire home/apt
# 2  56074   265650  -99.15605                           NaN  Entire home/apt
# 3  67703   334451  -99.16857                           NaN  Entire home/apt
# 4  70644   212109  -99.16217                           NaN  Entire home/apt
#
#          host_location host_response_rate host_is_superhost  \
# 0  Mexico City, Mexico                NaN                 f
# 1  Mexico City, Mexico               100%                 f
# 2  Mexico City, Mexico               100%                 f
# 3  Mexico City, Mexico               100%                 f
# 4  Mexico City, Mexico               100%                 t
#
#    host_total_listings_count host_identity_verified  ...  \
# 0                        1.0                      t  ...
# ...

# %%
#Columnas incrementales en un fator
#MÉTODO 2
columnas= df.iloc[:, 1::2] #Columnas con incrementos de 2 a partir de la columna 1
columnas
# Out:
#                         id    host_id  longitude  \
# 0                    35797     153786 -99.271780
# 1                    44616     196253 -99.177940
# 2                    56074     265650 -99.156050
# 3                    67703     334451 -99.168570
# 4                    70644     212109 -99.162170
# ...                    ...        ...        ...
# 26396  1450299137475327273  170416107 -99.174150
# 26397  1450300528106131951  358250534 -99.181881
# 26398  1450345027980478127  594251711 -99.175294
# 26399  1450394952972090126   24161895 -99.161810
# 26400  1450438287340754798  703177347 -99.175410
#
#        neighbourhood_group_cleansed        room_type        host_location  \
# 0                               NaN  Entire home/apt  Mexico City, Mexico
# 1                               NaN  Entire home/apt  Mexico City, Mexico
# 2                               NaN  Entire home/apt  Mexico City, Mexico
# 3                               NaN  Entire home/apt  Mexico City, Mexico
# ...

# %%
f8=columnas.to_csv("f8.csv", index=False)
